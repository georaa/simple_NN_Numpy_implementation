# %% [markdown]
# # Planar data classification with one hidden layer
#
# Welcome to your week 3 programming assignment. It's time to build your first neural network, which will have a hidden layer. You will see a big difference between this model and the one you implemented using logistic regression.
#
# **You will learn how to:**
# - Implement a 2-class classification neural network with a single hidden layer
# - Use units with a non-linear activation function, such as tanh
# - Compute the cross entropy loss
# - Implement forward and backward propagation

# %%
import numpy as np
import matplotlib.pyplot as plt
from testCases_v2 import *
import sklearn
import sklearn.datasets
import sklearn.linear_model
from planar_utils import plot_decision_boundary, sigmoid, load_planar_dataset, load_extra_datasets

# %matplotlib inline

np.random.seed(1) # set a seed so that the results are consistent

# %% [markdown]
# ## 2 - Dataset ##
#
# First, let's get the dataset you will work on. The following code will load a "flower" 2-class dataset into variables `X` and `Y`.

# %%
X, Y = load_planar_dataset()

# %%
plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral);

# %%
shape_X = X.shape
shape_Y = Y.shape
m = X.shape[1]
print ('The shape of X is: ' + str(shape_X))
print ('The shape of Y is: ' + str(shape_Y))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 400)
# The shape of Y is: (1, 400)
# I have m = 400 training examples!

# %%
# Train the logistic regression classifier
clf = sklearn.linear_model.LogisticRegressionCV();
clf.fit(X.T, Y.T);

# %%
plot_decision_boundary(lambda x: clf.predict(x), X, Y)
plt.title("Logistic Regression")

LR_predictions = clf.predict(X.T)
print ('Accuracy of logistic regression: %d ' % float((np.dot(Y,LR_predictions) + np.dot(1-Y,1-LR_predictions))/float(Y.size)*100) +
       '% ' + "(percentage of correctly labelled datapoints)")
# Out:
# Accuracy of logistic regression: 47 % (percentage of correctly labelled datapoints)

# %% [markdown]
# ## 4 - Neural Network model
#
# Logistic regression did not work well on the "flower dataset". You are going to train a Neural Network with a single hidden layer.
#
# **Here is our model**:
# <img src="images/classification_kiank.png" style="width:600px;height:300px;">
#
# **Mathematically**:
#
# For one example $x^{(i)}$:
# $$z^{[1] (i)} =  W^{[1]} x^{(i)} + b^{[1]}\tag{1}$$
# $$a^{[1] (i)} = \tanh(z^{[1] (i)})\tag{2}$$
# $$z^{[2] (i)} = W^{[2]} a^{[1] (i)} + b^{[2]}\tag{3}$$
# $$\hat{y}^{(i)} = a^{[2] (i)} = \sigma(z^{ [2] (i)})\tag{4}$$
# $$y^{(i)}_{prediction} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5 \\ 0 & \mbox{otherwise } \end{cases}\tag{5}$$
#
# Given the predictions on all the examples, you can also compute the cost $J$ as follows:
# $$J = - \frac{1}{m} \sum\limits_{i = 0}^{m} \large\left(\small y^{(i)}\log\left(a^{[2] (i)}\right) + (1-y^{(i)})\log\left(1- a^{[2] (i)}\right)  \large  \right) \small \tag{6}$$
#
# **Reminder**: The general methodology to build a Neural Network is to:
#     1. Define the neural network structure ( # of input units,  # of hidden units, etc).
#     2. Initialize the model's parameters
#     3. Loop:
#         - Implement forward propagation
#         - Compute loss
#         - Implement backward propagation to get the gradients
#         - Update parameters (gradient descent)
#
# You often build helper functions to compute steps 1-3 and then merge them into one function we call `nn_model()`. Once you've built `nn_model()` and learnt the right parameters, you can make predictions on new data.

# %%
def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    n_x = X.shape[0]
    n_h = 4
    n_y = Y.shape[0]

    return (n_x, n_h, n_y)

# %%
X_assess, Y_assess = layer_sizes_test_case()
(n_x, n_h, n_y) = layer_sizes(X_assess, Y_assess)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 5
# The size of the hidden layer is: n_h = 4
# The size of the output layer is: n_y = 2

# %%
def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    np.random.seed(2) 
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
n_x, n_h, n_y = initialize_parameters_test_case()

parameters = initialize_parameters(n_x, n_h, n_y)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[-0.00416758 -0.00056267]
#  [-0.02136196  0.01640271]
#  [-0.01793436 -0.00841747]
#  [ 0.00502881 -0.01245288]]
# b1 = [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# W2 = [[-0.01057952 -0.00909008  0.00551454  0.02292208]]
# b2 = [[ 0.]]

# %%
def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- The sigmoid output of the second activation
    cache -- a dictionary containing "Z1", "A1", "Z2" and "A2"
    """

    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']

    Z1 = W1 @ X + b1
    A1 = np.tanh(Z1)
    Z2 = W2 @ A1 + b2
    A2 = sigmoid(Z2)
    
    assert(A2.shape == (1, X.shape[1]))
    
    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
X_assess, parameters = forward_propagation_test_case()
A2, cache = forward_propagation(X_assess, parameters)

print(np.mean(cache['Z1']) ,np.mean(cache['A1']),np.mean(cache['Z2']),np.mean(cache['A2']))
# Out:
# 0.262818640198 0.091999045227 -1.30766601287 0.212877681719

# %%
def compute_cost(A2, Y, parameters):
    """
    Computes the cross-entropy cost given in equation (13)
    
    Arguments:
    A2 -- The sigmoid output of the second activation, of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    parameters -- python dictionary containing your parameters W1, b1, W2 and b2
    [Note that the parameters argument is not used in this function, 
    but the auto-grader currently expects this parameter.
    Future version of this notebook will fix both the notebook 
    and the auto-grader so that `parameters` is not needed.
    For now, please include `parameters` in the function signature,
    and also when invoking this function.]
    
    Returns:
    cost -- cross-entropy cost given equation (13)
    
    """
    
    m = Y.shape[1] 
    cost = - (np.log(A2) @ Y.T + np.log(1 - A2) @ (1 - Y).T) / m
   
    cost = float(np.squeeze(cost))  
    assert(isinstance(cost, float))
    
    return cost

# %%
A2, Y_assess, parameters = compute_cost_test_case()
print("cost = " + str(compute_cost(A2, Y_assess, parameters)))

# %%
print(A2.shape, Y_assess.shape)
Y_assess.T @ np.log(A2)
# Out:
# (1, 3) (1, 3)
# array([[-0.69268589, -0.6934306 , -0.69266804],
#        [-0.        , -0.        , -0.        ],
#        [-0.        , -0.        , -0.        ]])

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implement the backward propagation using the instructions above.
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- a dictionary containing "Z1", "A1", "Z2" and "A2".
    X -- input data of shape (2, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    grads -- python dictionary containing your gradients with respect to different parameters
    """
    m = X.shape[1]
    
    W1 = parameters['W1']
    W2 = parameters['W2']
 
    A1 = cache['A1']
    A2 = cache['A2']

    dZ2 = A2 - Y
    dW2 = (dZ2 @ A1.T) / m
    db2 = np.sum(dZ2, axis = 1, keepdims = True) / m
    dZ1 = (W2.T @ dZ2) * (1 - np.power(A1, 2))
    dW1 = (dZ1 @ X.T) / m
    db1 = np.sum(dZ1, axis = 1, keepdims = True) / m
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

# %%
parameters, cache, X_assess, Y_assess = backward_propagation_test_case()

grads = backward_propagation(parameters, cache, X_assess, Y_assess)
print ("dW1 = "+ str(grads["dW1"]))
print ("db1 = "+ str(grads["db1"]))
print ("dW2 = "+ str(grads["dW2"]))
print ("db2 = "+ str(grads["db2"]))
# Out:
# dW1 = [[ 0.00301023 -0.00747267]
#  [ 0.00257968 -0.00641288]
#  [-0.00156892  0.003893  ]
#  [-0.00652037  0.01618243]]
# db1 = [[ 0.00176201]
#  [ 0.00150995]
#  [-0.00091736]
#  [-0.00381422]]
# dW2 = [[ 0.00078841  0.01765429 -0.00084166 -0.01022527]]
# db2 = [[-0.16655712]]

# %%
def update_parameters(parameters, grads, learning_rate = 0.3):
    """
    Updates parameters using the gradient descent update rule given above
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    grads -- python dictionary containing your gradients 
    
    Returns:
    parameters -- python dictionary containing your updated parameters 
    """

    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']
 
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2 
    b2 = b2 - learning_rate * db2
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters, grads = update_parameters_test_case()
parameters = update_parameters(parameters, grads)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[-0.00622036  0.01751837]
#  [-0.02336459  0.03347354]
#  [-0.01682621 -0.01838453]
#  [ 0.00963293 -0.05261201]]
# b1 = [[ -9.29194481e-07]
#  [  9.30106438e-06]
#  [  6.61857177e-07]
#  [ -2.70954734e-06]]
# W2 = [[-0.01042663 -0.04130076  0.01644916  0.0451697 ]]
# b2 = [[  9.47631320e-05]]

# %%
def nn_model(X, Y, n_h, num_iterations = 10000, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (2, number of examples)
    Y -- labels of shape (1, number of examples)
    n_h -- size of the hidden layer
    num_iterations -- Number of iterations in gradient descent loop
    print_cost -- if True, print the cost every 1000 iterations
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    np.random.seed(3)
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    cost_cache = 1
    
    parameters = initialize_parameters(n_x, n_h, n_y)

    for i in range(0, num_iterations):
         
    
        A2, cache = forward_propagation(X, parameters)
        
        cost = compute_cost(A2, Y, parameters)
        if cost < cost_cache:
            cost_cache = cost
       
        grads = backward_propagation(parameters, cache, X, Y)
 
        if cost_cache == cost:
            parameters = update_parameters(parameters, grads)
        
        if print_cost and i % 1000 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
X_assess, Y_assess = nn_model_test_case()
parameters = nn_model(X_assess, Y_assess, 4, num_iterations=10000, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# Cost after iteration 0: 0.692739
# Cost after iteration 1000: 0.000218
# Cost after iteration 2000: 0.000107
# Cost after iteration 3000: 0.000071
# Cost after iteration 4000: 0.000053
# Cost after iteration 5000: 0.000042
# Cost after iteration 6000: 0.000035
# Cost after iteration 7000: 0.000030
# Cost after iteration 8000: 0.000026
# Cost after iteration 9000: 0.000023
# W1 = [[-0.65848169  1.21866811]
#  [-0.76204273  1.39377573]
#  [ 0.5792005  -1.10397703]
#  [ 0.76773391 -1.41477129]]
# b1 = [[ 0.287592  ]
#  [ 0.3511264 ]
#  [-0.2431246 ]
#  [-0.35772805]]
# W2 = [[-2.45566237 -3.27042274  2.00784958  3.36773273]]
# b2 = [[ 0.20459656]]

# %%
a2t, cache = forward_propagation(X_assess, parameters)
a2t2 = (a2t > 0.5)
a2t2
# Out:
# array([[ True, False,  True]], dtype=bool)

# %%
def predict(parameters, X):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (red: 0 / blue: 1)
    """
    
    A2, cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5)

    return predictions

# %%
parameters, X_assess = predict_test_case()

predictions = predict(parameters, X_assess)
print("predictions mean = " + str(np.mean(predictions)))
# Out:
# predictions mean = 0.666666666667

# %% [markdown]
# **Expected Output**:
#
#
# <table style="width:40%">
#   <tr>
#     <td>**predictions mean**</td>
#     <td> 0.666666666667 </td>
#   </tr>
#
# </table>

# %% [markdown]
# It is time to run the model and see how it performs on a planar dataset. Run the following code to test your model with a single hidden layer of $n_h$ hidden units.

# %%
# Build a model with a n_h-dimensional hidden layer
parameters = nn_model(X, Y, n_h = 4, num_iterations = 400000, print_cost=True)

# Plot the decision boundary
plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
plt.title("Decision Boundary for hidden layer size " + str(4))
# Out:
# Cost after iteration 0: 0.693048
# Cost after iteration 1000: 0.329237
# Cost after iteration 2000: 0.304689
# Cost after iteration 3000: 0.294878
# Cost after iteration 4000: 0.288420
# Cost after iteration 5000: 0.283449
# Cost after iteration 6000: 0.279373
# Cost after iteration 7000: 0.275723
# Cost after iteration 8000: 0.271143
# Cost after iteration 9000: 0.249617
# Cost after iteration 10000: 0.242687
# Cost after iteration 11000: 0.238131
# Cost after iteration 12000: 0.234841
# Cost after iteration 13000: 0.232311
# Cost after iteration 14000: 0.230274
# Cost after iteration 15000: 0.228578
# Cost after iteration 16000: 0.227127
# Cost after iteration 17000: 0.225862
# Cost after iteration 18000: 0.224741
# Cost after iteration 19000: 0.223736
# Cost after iteration 20000: 0.222825
# Cost after iteration 21000: 0.221993
# Cost after iteration 22000: 0.221228
# Cost after iteration 23000: 0.220519
# Cost after iteration 24000: 0.219860
# Cost after iteration 25000: 0.219243
# Cost after iteration 26000: 0.218665
# Cost after iteration 27000: 0.218120
# Cost after iteration 28000: 0.217607
# Cost after iteration 29000: 0.217123
# Cost after iteration 30000: 0.216665
# Cost after iteration 31000: 0.216231
# Cost after iteration 32000: 0.215820
# Cost after iteration 33000: 0.215430
# Cost after iteration 34000: 0.215060
# Cost after iteration 35000: 0.214708
# Cost after iteration 36000: 0.214373
# Cost after iteration 37000: 0.214054
# Cost after iteration 38000: 0.213750
# Cost after iteration 39000: 0.213459
# Cost after iteration 40000: 0.213182
# Cost after iteration 41000: 0.212917
# Cost after iteration 42000: 0.212663
# Cost after iteration 43000: 0.212421
# Cost after iteration 44000: 0.212188
# Cost after iteration 45000: 0.211965
# Cost after iteration 46000: 0.211751
# Cost after iteration 47000: 0.211545
# Cost after iteration 48000: 0.211347
# Cost after iteration 49000: 0.211157
# Cost after iteration 50000: 0.210974
# Cost after iteration 51000: 0.210797
# Cost after iteration 52000: 0.210627
# Cost after iteration 53000: 0.210463
# Cost after iteration 54000: 0.210305
# Cost after iteration 55000: 0.210152
# Cost after iteration 56000: 0.210004
# Cost after iteration 57000: 0.209861
# Cost after iteration 58000: 0.209723
# Cost after iteration 59000: 0.209589
# Cost after iteration 60000: 0.209459
# Cost after iteration 61000: 0.209334
# Cost after iteration 62000: 0.209212
# Cost after iteration 63000: 0.209093
# Cost after iteration 64000: 0.208979
# Cost after iteration 65000: 0.208867
# Cost after iteration 66000: 0.208759
# Cost after iteration 67000: 0.208653
# Cost after iteration 68000: 0.208551
# Cost after iteration 69000: 0.208451
# Cost after iteration 70000: 0.208354
# Cost after iteration 71000: 0.208260
# Cost after iteration 72000: 0.208167
# Cost after iteration 73000: 0.208078
# Cost after iteration 74000: 0.207990
# Cost after iteration 75000: 0.207904
# Cost after iteration 76000: 0.207821
# Cost after iteration 77000: 0.207739
# Cost after iteration 78000: 0.207660
# Cost after iteration 79000: 0.207582
# Cost after iteration 80000: 0.207506
# Cost after iteration 81000: 0.207431
# Cost after iteration 82000: 0.207359
# Cost after iteration 83000: 0.207287
# Cost after iteration 84000: 0.207218
# Cost after iteration 85000: 0.207149
# Cost after iteration 86000: 0.207082
# Cost after iteration 87000: 0.207017
# Cost after iteration 88000: 0.206952
# Cost after iteration 89000: 0.206889
# Cost after iteration 90000: 0.206827
# Cost after iteration 91000: 0.206766
# Cost after iteration 92000: 0.206707
# Cost after iteration 93000: 0.206648
# Cost after iteration 94000: 0.206590
# Cost after iteration 95000: 0.206534
# Cost after iteration 96000: 0.206478
# Cost after iteration 97000: 0.206424
# Cost after iteration 98000: 0.206370
# Cost after iteration 99000: 0.206317
# Cost after iteration 100000: 0.206265
# Cost after iteration 101000: 0.206214
# Cost after iteration 102000: 0.206163
# Cost after iteration 103000: 0.206114
# Cost after iteration 104000: 0.206065
# Cost after iteration 105000: 0.206017
# Cost after iteration 106000: 0.205969
# Cost after iteration 107000: 0.205922
# Cost after iteration 108000: 0.205876
# Cost after iteration 109000: 0.205831
# Cost after iteration 110000: 0.205786
# Cost after iteration 111000: 0.205741
# Cost after iteration 112000: 0.205698
# Cost after iteration 113000: 0.205655
# Cost after iteration 114000: 0.205612
# Cost after iteration 115000: 0.205570
# Cost after iteration 116000: 0.205528
# Cost after iteration 117000: 0.205487
# Cost after iteration 118000: 0.205447
# Cost after iteration 119000: 0.205407
# Cost after iteration 120000: 0.205367
# Cost after iteration 121000: 0.205328
# Cost after iteration 122000: 0.205289
# Cost after iteration 123000: 0.205251
# Cost after iteration 124000: 0.205213
# Cost after iteration 125000: 0.205176
# Cost after iteration 126000: 0.205139
# Cost after iteration 127000: 0.205102
# Cost after iteration 128000: 0.205066
# Cost after iteration 129000: 0.205030
# Cost after iteration 130000: 0.204994
# Cost after iteration 131000: 0.204959
# Cost after iteration 132000: 0.204924
# Cost after iteration 133000: 0.204890
# Cost after iteration 134000: 0.204855
# Cost after iteration 135000: 0.204821
# Cost after iteration 136000: 0.204788
# Cost after iteration 137000: 0.204754
# Cost after iteration 138000: 0.204721
# Cost after iteration 139000: 0.204688
# Cost after iteration 140000: 0.204656
# Cost after iteration 141000: 0.204624
# Cost after iteration 142000: 0.204592
# Cost after iteration 143000: 0.204560
# Cost after iteration 144000: 0.204528
# Cost after iteration 145000: 0.204497
# Cost after iteration 146000: 0.204466
# Cost after iteration 147000: 0.204435
# Cost after iteration 148000: 0.204405
# Cost after iteration 149000: 0.204374
# Cost after iteration 150000: 0.204344
# Cost after iteration 151000: 0.204314
# Cost after iteration 152000: 0.204285
# Cost after iteration 153000: 0.204255
# Cost after iteration 154000: 0.204226
# Cost after iteration 155000: 0.204197
# Cost after iteration 156000: 0.204168
# Cost after iteration 157000: 0.204139
# Cost after iteration 158000: 0.204110
# Cost after iteration 159000: 0.204082
# Cost after iteration 160000: 0.204053
# Cost after iteration 161000: 0.204025
# Cost after iteration 162000: 0.203997
# Cost after iteration 163000: 0.203970
# Cost after iteration 164000: 0.203942
# Cost after iteration 165000: 0.203914
# Cost after iteration 166000: 0.203887
# Cost after iteration 167000: 0.203860
# Cost after iteration 168000: 0.203833
# Cost after iteration 169000: 0.203806
# Cost after iteration 170000: 0.203779
# Cost after iteration 171000: 0.203752
# Cost after iteration 172000: 0.203726
# Cost after iteration 173000: 0.203699
# Cost after iteration 174000: 0.203673
# Cost after iteration 175000: 0.203647
# Cost after iteration 176000: 0.203621
# Cost after iteration 177000: 0.203595
# Cost after iteration 178000: 0.203569
# Cost after iteration 179000: 0.203543
# Cost after iteration 180000: 0.203518
# Cost after iteration 181000: 0.203492
# Cost after iteration 182000: 0.203467
# Cost after iteration 183000: 0.203441
# Cost after iteration 184000: 0.203416
# Cost after iteration 185000: 0.203391
# Cost after iteration 186000: 0.203366
# Cost after iteration 187000: 0.203341
# Cost after iteration 188000: 0.203316
# Cost after iteration 189000: 0.203291
# Cost after iteration 190000: 0.203267
# Cost after iteration 191000: 0.203242
# Cost after iteration 192000: 0.203217
# Cost after iteration 193000: 0.203193
# Cost after iteration 194000: 0.203168
# Cost after iteration 195000: 0.203144
# Cost after iteration 196000: 0.203120
# Cost after iteration 197000: 0.203096
# Cost after iteration 198000: 0.203072
# Cost after iteration 199000: 0.203048
# Cost after iteration 200000: 0.203024
# Cost after iteration 201000: 0.203000
# Cost after iteration 202000: 0.202976
# Cost after iteration 203000: 0.202952
# Cost after iteration 204000: 0.202928
# Cost after iteration 205000: 0.202905
# Cost after iteration 206000: 0.202881
# Cost after iteration 207000: 0.202858
# Cost after iteration 208000: 0.202834
# Cost after iteration 209000: 0.202811
# Cost after iteration 210000: 0.202787
# Cost after iteration 211000: 0.202764
# Cost after iteration 212000: 0.202741
# Cost after iteration 213000: 0.202717
# Cost after iteration 214000: 0.202694
# Cost after iteration 215000: 0.202671
# Cost after iteration 216000: 0.202648
# Cost after iteration 217000: 0.202625
# Cost after iteration 218000: 0.202602
# Cost after iteration 219000: 0.202579
# Cost after iteration 220000: 0.202556
# Cost after iteration 221000: 0.202533
# Cost after iteration 222000: 0.202510
# Cost after iteration 223000: 0.202488
# Cost after iteration 224000: 0.202465
# Cost after iteration 225000: 0.202442
# Cost after iteration 226000: 0.202419
# Cost after iteration 227000: 0.202397
# Cost after iteration 228000: 0.202374
# Cost after iteration 229000: 0.202352
# Cost after iteration 230000: 0.202329
# Cost after iteration 231000: 0.202306
# Cost after iteration 232000: 0.202284
# Cost after iteration 233000: 0.202261
# Cost after iteration 234000: 0.202239
# Cost after iteration 235000: 0.202217
# Cost after iteration 236000: 0.202194
# Cost after iteration 237000: 0.202172
# Cost after iteration 238000: 0.202150
# Cost after iteration 239000: 0.202127
# Cost after iteration 240000: 0.202105
# Cost after iteration 241000: 0.202083
# Cost after iteration 242000: 0.202060
# Cost after iteration 243000: 0.202038
# Cost after iteration 244000: 0.202016
# Cost after iteration 245000: 0.201994
# Cost after iteration 246000: 0.201972
# Cost after iteration 247000: 0.201950
# Cost after iteration 248000: 0.201927
# Cost after iteration 249000: 0.201905
# Cost after iteration 250000: 0.201883
# Cost after iteration 251000: 0.201861
# Cost after iteration 252000: 0.201839
# Cost after iteration 253000: 0.201817
# Cost after iteration 254000: 0.201795
# Cost after iteration 255000: 0.201773
# Cost after iteration 256000: 0.201751
# Cost after iteration 257000: 0.201729
# Cost after iteration 258000: 0.201707
# Cost after iteration 259000: 0.201685
# Cost after iteration 260000: 0.201663
# Cost after iteration 261000: 0.201641
# Cost after iteration 262000: 0.201619
# Cost after iteration 263000: 0.201598
# Cost after iteration 264000: 0.201576
# Cost after iteration 265000: 0.201554
# Cost after iteration 266000: 0.201532
# Cost after iteration 267000: 0.201510
# Cost after iteration 268000: 0.201488
# Cost after iteration 269000: 0.201466
# Cost after iteration 270000: 0.201444
# Cost after iteration 271000: 0.201423
# Cost after iteration 272000: 0.201401
# Cost after iteration 273000: 0.201379
# Cost after iteration 274000: 0.201357
# Cost after iteration 275000: 0.201335
# Cost after iteration 276000: 0.201314
# Cost after iteration 277000: 0.201292
# Cost after iteration 278000: 0.201270
# Cost after iteration 279000: 0.201248
# Cost after iteration 280000: 0.201226
# Cost after iteration 281000: 0.201205
# Cost after iteration 282000: 0.201183
# Cost after iteration 283000: 0.201161
# Cost after iteration 284000: 0.201139
# Cost after iteration 285000: 0.201118
# Cost after iteration 286000: 0.201096
# Cost after iteration 287000: 0.201074
# Cost after iteration 288000: 0.201052
# Cost after iteration 289000: 0.201030
# Cost after iteration 290000: 0.201009
# Cost after iteration 291000: 0.200987
# Cost after iteration 292000: 0.200965
# Cost after iteration 293000: 0.200943
# Cost after iteration 294000: 0.200922
# Cost after iteration 295000: 0.200900
# Cost after iteration 296000: 0.200878
# Cost after iteration 297000: 0.200856
# Cost after iteration 298000: 0.200835
# Cost after iteration 299000: 0.200813
# Cost after iteration 300000: 0.200791
# Cost after iteration 301000: 0.200769
# Cost after iteration 302000: 0.200747
# Cost after iteration 303000: 0.200726
# Cost after iteration 304000: 0.200704
# Cost after iteration 305000: 0.200682
# Cost after iteration 306000: 0.200660
# Cost after iteration 307000: 0.200638
# Cost after iteration 308000: 0.200617
# Cost after iteration 309000: 0.200595
# Cost after iteration 310000: 0.200573
# Cost after iteration 311000: 0.200551
# Cost after iteration 312000: 0.200529
# Cost after iteration 313000: 0.200507
# Cost after iteration 314000: 0.200486
# Cost after iteration 315000: 0.200464
# Cost after iteration 316000: 0.200442
# Cost after iteration 317000: 0.200420
# Cost after iteration 318000: 0.200398
# Cost after iteration 319000: 0.200376
# Cost after iteration 320000: 0.200354
# Cost after iteration 321000: 0.200333
# Cost after iteration 322000: 0.200311
# Cost after iteration 323000: 0.200289
# Cost after iteration 324000: 0.200267
# Cost after iteration 325000: 0.200245
# Cost after iteration 326000: 0.200223
# Cost after iteration 327000: 0.200201
# Cost after iteration 328000: 0.200179
# Cost after iteration 329000: 0.200157
# Cost after iteration 330000: 0.200135
# Cost after iteration 331000: 0.200113
# Cost after iteration 332000: 0.200091
# Cost after iteration 333000: 0.200069
# Cost after iteration 334000: 0.200047
# Cost after iteration 335000: 0.200025
# Cost after iteration 336000: 0.200003
# Cost after iteration 337000: 0.199981
# Cost after iteration 338000: 0.199959
# Cost after iteration 339000: 0.199937
# Cost after iteration 340000: 0.199915
# Cost after iteration 341000: 0.199893
# Cost after iteration 342000: 0.199871
# Cost after iteration 343000: 0.199849
# Cost after iteration 344000: 0.199827
# Cost after iteration 345000: 0.199805
# Cost after iteration 346000: 0.199782
# Cost after iteration 347000: 0.199760
# Cost after iteration 348000: 0.199738
# Cost after iteration 349000: 0.199716
# Cost after iteration 350000: 0.199694
# Cost after iteration 351000: 0.199672
# Cost after iteration 352000: 0.199649
# Cost after iteration 353000: 0.199627
# Cost after iteration 354000: 0.199605
# Cost after iteration 355000: 0.199583
# Cost after iteration 356000: 0.199561
# Cost after iteration 357000: 0.199538
# Cost after iteration 358000: 0.199516
# Cost after iteration 359000: 0.199494
# Cost after iteration 360000: 0.199471
# Cost after iteration 361000: 0.199449
# Cost after iteration 362000: 0.199427
# Cost after iteration 363000: 0.199404
# Cost after iteration 364000: 0.199382
# Cost after iteration 365000: 0.199360
# Cost after iteration 366000: 0.199337
# Cost after iteration 367000: 0.199315
# Cost after iteration 368000: 0.199292
# Cost after iteration 369000: 0.199270
# Cost after iteration 370000: 0.199248
# Cost after iteration 371000: 0.199225
# Cost after iteration 372000: 0.199203
# Cost after iteration 373000: 0.199180
# Cost after iteration 374000: 0.199158
# Cost after iteration 375000: 0.199135
# Cost after iteration 376000: 0.199113
# Cost after iteration 377000: 0.199090
# Cost after iteration 378000: 0.199068
# Cost after iteration 379000: 0.199045
# Cost after iteration 380000: 0.199022
# Cost after iteration 381000: 0.199000
# Cost after iteration 382000: 0.198977
# Cost after iteration 383000: 0.198955
# Cost after iteration 384000: 0.198932
# Cost after iteration 385000: 0.198909
# Cost after iteration 386000: 0.198887
# Cost after iteration 387000: 0.198864
# Cost after iteration 388000: 0.198841
# Cost after iteration 389000: 0.198818
# Cost after iteration 390000: 0.198796
# Cost after iteration 391000: 0.198773
# Cost after iteration 392000: 0.198750
# Cost after iteration 393000: 0.198727
# Cost after iteration 394000: 0.198705
# Cost after iteration 395000: 0.198682
# Cost after iteration 396000: 0.198659
# Cost after iteration 397000: 0.198636
# Cost after iteration 398000: 0.198613
# Cost after iteration 399000: 0.198590

# %%
# Print accuracy
predictions = predict(parameters, X)
print ('Accuracy: %d' % float((np.dot(Y,predictions.T) + np.dot(1-Y,1-predictions.T))/float(Y.size)*100) + '%')
# Out:
# Accuracy: 91%
